# %%
import requests

# %%
import requests

cookies = {
    'cookie-dismissed': '1',
    'sap-appcontext': 'c2FwLXNlc3Npb25pZD1TSUQlM2FBTk9OJTNhVk1FU1AxMDFfRVNQXzAwJTNhem1QM3ZWbHRlMXRUSXNKUWRoOWxDMjdoZjFvcDlhSjFTQ09Pc3YzZy1BVFQ%3d',
    'BCSIG_sap-appcontext': 'mFVpGrXNy+61L9tbsLtB4RH5Wf8euVizKe7isFYW2yA=',
    'sap-usercontext': 'sap-language=D&sap-client=010',
    'BCSIG_sap-usercontext': 'JPPXBkJvBI9BG/lwh0PNYXbXrwVu6KCKr1N5ID2xh4o=',
}

headers = {
    'Origin': 'https://shop.hgc.ch',
    'Accept-Encoding': 'gzip, deflate, br',
    'Accept-Language': 'de-CH,de-DE;q=0.9,de;q=0.8,en-US;q=0.7,en;q=0.6',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.77 Safari/537.36',
    'Content-Type': 'application/x-www-form-urlencoded; charset=UTF-8',
    'Accept': 'application/json, text/javascript, */*; q=0.01',
    'Referer': 'https://shop.hgc.ch/FIS(bD1kZSZjPTAxMA==)/FISESALES/search.htm?q=',
    'X-Requested-With': 'XMLHttpRequest',
    'Connection': 'keep-alive',
}

params = (
    ('event', 'GET_DETAILS'),
    ('pitcher', 'search.htm'),
    ('receiver', ''),
)

data = {
  'matnr': '000000000100061495',
  'menge': '',
  'doctype': '',
  'docid': '',
  'posnr': '',
  'meins': 'KG'
}

response = requests.post('https://shop.hgc.ch/FIS(bD1kZSZjPTAxMA==)/FISESALES/details.ws', headers=headers, params=params, cookies=cookies, data=data)

# %%
response.json()
# Out:
# {'event': 'GET_DETAILS',
#  'message': '',
#  'no_oltp': '',
#  'output': {'additional_infos': [],
#   'additional_material': {},
#   'basis_me': 'SAC',
#   'basket_count': 0,
#   'beschreibung': 'Schnellabbindender, polymer-modifizierter, faserverstärkter Mörtel mit Korrosionsschutz. Vorwiegend bei hohen Ansprüchen für Reparaturmörtel im Beton und Bauteile, welche in aggressive Umweltkonditionen exponiert sind. Schützt Armierungen.',
#   'bismt': '100061495',
#   'brgew': '25.000 ',
#   'bstme': '',
#   'buildup_lnk': '',
#   'catalogue_path': [{'catalogue_id': '0029117717',
#     'catalogue_name': '',
#     'category_id': '',
#     'category_index': '000074',
#     'category_name': 'Trockenbeton, -mörtel, Porenbetonkleber, Fliessestriche',
#     'hierarchy_level': 1},
#    {'catalogue_id': '0029117717',
#     'catalogue_name': '',
#     'category_id': '',
#     'category_index': '000221',
#     'category_name': 'Mörtel Thoro',
#     'hierarchy_level': 2},
# ...

# %%
r = requests.get("https://shop.hgc.ch")

# %%
r.headers['Set-Cookie']
# Out:
# 'sap-usercontext=sap-language=D&sap-client=010; path=/, BCSIG_sap-usercontext=JPPXBkJvBI9BG/lwh0PNYXbXrwVu6KCKr1N5ID2xh4o=; path=/'

# %%
from selenium import webdriver

# %%
driver = webdriver.Chrome()

# %%
driver.get('https://shop.hgc.ch')

cookies = driver.get_cookies()

# %%
cookies[0]['name']
# Out:
# 'sap-appcontext'

# %%
{i['name']: i['value'] for i in cookies}
# Out:
# {'BCSIG_sap-appcontext': 'g8cDf+hLSTkzzfWTEnyQ3HIY4L9KXVUwQcEga5LQdqg=',
#  'BCSIG_sap-usercontext': 'JPPXBkJvBI9BG/lwh0PNYXbXrwVu6KCKr1N5ID2xh4o=',
#  '_ga': 'GA1.2.2146247786.1541940761',
#  '_gat_UA-73334028-2': '1',
#  '_gid': 'GA1.2.812767252.1541940761',
#  'sap-appcontext': 'c2FwLXNlc3Npb25pZD1TSUQlM2FBTk9OJTNhVk1FU1AxMDFfRVNQXzAwJTNhem1QM1UxbW5fdklTWkRjcVk3OXE5enpDVXdncDlhTHBTaU9BOXFFOC1BVFQ%3d',
#  'sap-usercontext': 'sap-language=D&sap-client=010'}

# %%
import json
def load_ids():
    with open('ids.json') as f:
        js = json.load(f)
    return [i['id'] for i in js]

# %%
load_ids()
# Out:
# ['000000000100044107',
#  '000000000100082269',
#  '000000000100082350',
#  '000000000100082518',
#  '000000000100082519',
#  '000000000100066953',
#  '000000000100066954',
#  '000000000100044314',
#  '000000000100044350',
#  '000000000100017846',
#  '000000000100044107',
#  '000000000100082269',
#  '000000000100082350',
#  '000000000100082518',
#  '000000000100082519',
#  '000000000100066953',
#  '000000000100066954',
#  '000000000100044314',
#  '000000000100044350',
#  '000000000100017846',
#  '000000000100044107',
#  '000000000100082269',
#  '000000000100082350',
#  '000000000100082518',
#  '000000000100082519',
#  '000000000100066953',
#  '000000000100066954',
#  '000000000100044314',
#  '000000000100044350',
#  '000000000100017846',
#  '000000000100044107',
#  '000000000100082269',
#  '000000000100082350',
#  '000000000100082518',
#  '000000000100082519',
#  '000000000100066953',
#  '000000000100066954',
#  '000000000100044314',
#  '000000000100044350',
#  '000000000100017846',
# ...

# %%
driver.close()
